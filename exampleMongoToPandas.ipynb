# %%
import pandas as pd
from pymongo import MongoClient

# Buat koneksi ke MongoDB
uri ="mongodb+srv://admin:admin@doni-playground.cv49f.mongodb.net"
database_name = "Soil-Polution"
client = MongoClient(uri)
database = client[database_name]

# %%
#example untuk table case
case_collection = database["Case"]
query = {}
cursor = case_collection.find(query, {'_id': False})
case_table = pd.DataFrame(list(cursor))

# %% [markdown]
# List Nama table:
# - Case
# - Disease
# - Farm
# - Pollutant
# - Soil

# %%
case_table.head(5)
# Out:
#        Case_ID Date_Reported    Country Pollutant_ID Soil_ID Farm_ID  \
# 0  CASE_100000    2024-09-12   Pakistan        Pol-1  Soil-1  Farm-1
# 1  CASE_100001    2024-01-01    Germany        Pol-2  Soil-2  Farm-2
# 2  CASE_100002    2025-02-24    Germany        Pol-3  Soil-3  Farm-3
# 3  CASE_100004    2023-05-24      India        Pol-4  Soil-4  Farm-4
# 4  CASE_100006    2024-05-07  Australia        Pol-5  Soil-5  Farm-5
#
#   Disease_ID     Mitigation_Measure  Case_Resolved  Follow_Up_Required
# 0  Disease-1  Government Regulation          False                True
# 1  Disease-2    Community Awareness           True               False
# 2  Disease-3       Soil Remediation           True               False
# 3  Disease-4  Government Regulation           True                True
# 4  Disease-5    Community Awareness          False                True
